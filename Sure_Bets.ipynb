# %%
# Imports
import requests 
import json

# %%
requests = requests.get("http://api.sportradar.us/americanfootball/trial/v2/en/players/mappings.json?api_key=scgt6n3u94gveq9d647hrbpk")
https://api.sportradar.us/nfl/official/trial/v7/en/games/{game_id}/statistics.json?api_key=scgt6n3u94gveq9d647hrbpk

#import http.client

#conn = http.client.HTTPSConnection("api.sportradar.us")

#conn.request("GET", "/nfl/official/trial/v7/en/games/7d06369a-382a-448a-b295-6da9eab53245/pbp.xml?api_key={your_api_key}")

#res = conn.getresponse()
#data = res.read()

#print(data.decode("utf-8"))

# %%
requests.status_code
# Out:
# 200

# %%
requests.json()
# Out:
# {'generated_at': '2022-09-07T03:41:54+00:00',
#  'mappings': [{'external_id': '1bac1a70-2e18-11ed-9297-95e02748588d',
#    'id': 'sr:player:2437045'},
#   {'external_id': '18776e90-15a9-11ed-b058-57ba1671f694',
#    'id': 'sr:player:2437035'},
#   {'external_id': 'cfe012cf-57de-438f-8e65-63f09b6878c5',
#    'id': 'sr:player:2437033'},
#   {'external_id': '6f6ea3a0-011b-11ed-b8ce-d54c28df9221',
#    'id': 'sr:player:2437031'},
#   {'external_id': 'afc3cd02-f7fb-4de3-9e4f-46f02f7fd9b8',
#    'id': 'sr:player:1193068'},
#   {'external_id': '29477d70-07a6-11ed-864e-01ce8d5fbd03',
#    'id': 'sr:player:2437027'},
#   {'external_id': '92afe19e-2cc6-4533-a24b-5a5480560363',
#    'id': 'sr:player:2437023'},
#   {'external_id': '64d6a240-fc6f-11ec-926a-795e74e5a039',
#    'id': 'sr:player:2436987'},
#   {'external_id': '79243c20-d550-405b-afee-f54e14f1b403',
#    'id': 'sr:player:2220998'},
#   {'external_id': '713bb260-146a-11ed-82e6-6fe596000b9f',
#    'id': 'sr:player:2436911'},
# ...

# %%
import pandas as pd
pd.DataFrame(requests.json())
# Out:
#                   generated_at  \
# 0    2022-09-07T03:41:54+00:00
# 1    2022-09-07T03:41:54+00:00
# 2    2022-09-07T03:41:54+00:00
# 3    2022-09-07T03:41:54+00:00
# 4    2022-09-07T03:41:54+00:00
# ..                         ...
# 995  2022-09-07T03:41:54+00:00
# 996  2022-09-07T03:41:54+00:00
# 997  2022-09-07T03:41:54+00:00
# 998  2022-09-07T03:41:54+00:00
# 999  2022-09-07T03:41:54+00:00
#
#                                               mappings
# 0    {'external_id': '1bac1a70-2e18-11ed-9297-95e02...
# 1    {'external_id': '18776e90-15a9-11ed-b058-57ba1...
# 2    {'external_id': 'cfe012cf-57de-438f-8e65-63f09...
# 3    {'external_id': '6f6ea3a0-011b-11ed-b8ce-d54c2...
# 4    {'external_id': 'afc3cd02-f7fb-4de3-9e4f-46f02...
# ..                                                 ...
# 995  {'external_id': 'fed4dd30-224e-11ed-94e5-c5e89...
# 996  {'external_id': '8c1e3a40-2251-11ed-941e-e708f...
# 997  {'external_id': 'c8cff180-225c-11ed-8c96-cf524...
# ...
