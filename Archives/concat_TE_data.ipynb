# %%
import pandas as pd

# %%
wk1_22TE = pd.read_csv('./csv_files/Stats_TE_2021_WK1.csv')
wk1_22TE.head()
# Out:
#    Rank                Player    REC    TGT    YDS   Y/R    LG   20+   TD  \
# 0   1.0    Mark Andrews (BAL)  107.0  153.0  1,361  12.7  43.0  27.0  9.0
# 1   2.0     Travis Kelce (KC)   92.0  134.0  1,125  12.2  69.0  20.0  9.0
# 2   3.0  Dalton Schultz (DAL)   78.0  104.0    808  10.4  32.0   8.0  8.0
# 3   4.0    George Kittle (SF)   71.0   94.0    910  12.8  48.0  17.0  6.0
# 4   5.0   Rob Gronkowski (FA)   55.0   88.0    802  14.6  42.0  20.0  6.0
#
#    ATT  YDS.1  TD.1   FL     G   FPTS  FPTS/G    ROST
# 0  1.0    0.0   0.0  0.0  17.0  194.1    11.4  100.0%
# 1  2.0    3.0   1.0  1.0  16.0  170.8    10.7  100.0%
# 2  0.0    0.0   0.0  0.0  17.0  130.8     7.7   98.3%
# 3  3.0   20.0   0.0  1.0  14.0  127.0     9.1   99.5%
# 4  0.0    0.0   0.0  0.0  12.0  116.2     9.7    2.6%

# %%
wk1_22TE = wk1_22TE(['Player'], [
