# %%
# Imports
import requests
import json
import pandas as pd
import numpy as np
from pathlib import Path
import os
from dotenv import load_dotenv
import matplotlib.pyplot as plt

# %%
# Create link to NFL api on Sport Radar
request = requests.get("http://api.sportradar.us/nfl/official/trial/v7/en/seasons/2021/REG/teams/97354895-8c77-4fd4-a860-32e62ea7382a/statistics.json?api_key=n348bxq8f6g6z9e2cfseqzk5").json()

# %%
# Response type
type(request)
# Out:
# dict

# %%
# Print the response
print(json.dumps(request, indent=3, sort_keys=True))
# Out:
# {
#    "_comment": "Generation started @ 2022-09-07 18:00:41 UTC ended @ 2022-09-07 18:00:41 UTC",
#    "alias": "NE",
#    "id": "97354895-8c77-4fd4-a860-32e62ea7382a",
#    "market": "New England",
#    "name": "Patriots",
#    "opponents": {
#       "defense": {
#          "assists": 337,
#          "batted_passes": 9,
#          "blitzes": 236,
#          "combined": 1043,
#          "def_comps": 378,
#          "def_targets": 553,
#          "forced_fumbles": 11,
#          "fumble_recoveries": 9,
#          "hurries": 34,
#          "interceptions": 13,
#          "knockdowns": 48,
#          "misc_assists": 0,
#          "misc_forced_fumbles": 0,
#          "misc_fumble_recoveries": 0,
#          "misc_tackles": 5,
#          "missed_tackles": 112,
#          "passes_defended": 62,
#          "qb_hits": 81,
#          "sack_yards": 241.0,
#          "sacks": 28.0,
#          "safeties": 0,
#          "sp_assists": 19,
#          "sp_blocks": 4,
#          "sp_forced_fumbles": 1,
#          "sp_fumble_recoveries": 0,
#          "sp_tackles": 44,
#          "tackles": 706,
#          "tloss": 77.0,
#          "tloss_yards": 280.0
#       },
#       "efficiency": {
#          "fourthdown": {
#             "attempts": 32,
#             "pct": 53.125,
#             "successes": 17
#          },
#          "goaltogo": {
#             "attempts": 23,
#             "pct": 60.87,
#             "successes": 14
#          },
#          "redzone": {
#             "attempts": 48,
#             "pct": 47.917,
#             "successes": 23
#          },
#          "thirddown": {
#             "attempts": 211,
#             "pct": 36.493,
#             "successes": 77
#          }
#       },
#       "extra_points": {
#          "conversions": {
#             "defense_attempts": 0,
#             "defense_successes": 0,
#             "pass_attempts": 2,
#             "pass_successes": 0,
#             "rush_attempts": 1,
#             "rush_successes": 0,
#             "turnover_successes": 0
#          },
#          "kicks": {
#             "attempts": 30,
#             "blocked": 0,
#             "made": 27,
#             "pct": 90.0
#          }
#       },
#       "field_goals": {
#          "attempts": 33,
#          "attempts_19": 0,
#          "attempts_29": 6,
#          "attempts_39": 10,
#          "attempts_49": 12,
#          "attempts_50": 5,
#          "avg_yards": 24.636,
#          "blocked": 0,
#          "longest": 49,
#          "made": 22,
#          "made_19": 0,
#          "made_29": 6,
#          "made_39": 7,
#          "made_49": 9,
#          "made_50": 0,
#          "missed": 11,
#          "pct": 66.667,
#          "yards": 813
#       },
#       "first_downs": {
#          "pass": 176,
#          "penalty": 21,
#          "rush": 111,
#          "total": 308
#       },
#       "fumbles": {
#          "ez_rec_tds": 1,
#          "forced_fumbles": 12,
#          "fumbles": 14,
#          "lost_fumbles": 7,
#          "opp_rec": 10,
#          "opp_rec_tds": 1,
#          "opp_rec_yards": 17,
#          "out_of_bounds": 0,
#          "own_rec": 6,
#          "own_rec_tds": 0,
#          "own_rec_yards": -7
#       },
#       "games_played": 17,
#       "int_returns": {
#          "avg_yards": 20.154,
#          "longest": 46,
#          "longest_touchdown": 42,
#          "returns": 13,
#          "touchdowns": 3,
#          "yards": 262
#       },
#       "interceptions": {
#          "interceptions": 13,
#          "return_yards": 262,
#          "returned": 13
#       },
#       "kick_returns": {
#          "avg_yards": 21.2,
#          "faircatches": 0,
#          "longest": 38,
#          "longest_touchdown": 0,
#          "returns": 55,
#          "touchdowns": 0,
#          "yards": 1166
#       },
#       "kickoffs": {
#          "endzone": 7,
#          "inside_20": 4,
#          "kickoffs": 72,
#          "onside_attempts": 1,
#          "onside_successes": 0,
#          "out_of_bounds": 3,
#          "return_yards": 601,
#          "returned": 0,
#          "squib_kicks": 1,
#          "touchbacks": 44,
#          "yards": 4550
#       },
#       "misc_returns": {
#          "blk_fg_touchdowns": 0,
#          "blk_punt_touchdowns": 1,
#          "ez_rec_touchdowns": 0,
#          "fg_return_touchdowns": 0,
#          "longest_touchdown": 0,
#          "returns": 3,
#          "touchdowns": 1,
#          "yards": 4
#       },
#       "passing": {
#          "air_yards": 1815,
#          "attempts": 538,
#          "avg_yards": 6.388,
#          "batted_passes": 12,
#          "blitzes": 138,
#          "cmp_pct": 59.294,
#          "completions": 319,
#          "defended_passes": 71,
#          "dropped_passes": 24,
#          "gross_yards": 3437,
#          "hurries": 63,
#          "int_touchdowns": 0,
#          "interceptions": 23,
#          "knockdowns": 43,
#          "longest": 67,
#          "longest_touchdown": 67,
#          "net_yards": 3181,
#          "on_target_throws": 374,
#          "pocket_time": 1458.048,
#          "poor_throws": 103,
#          "rating": 73.3,
#          "redzone_attempts": 67,
#          "sack_yards": 256,
#          "sacks": 36,
#          "spikes": 0,
#          "throw_aways": 21,
#          "touchdowns": 21,
#          "yards": 3181
#       },
#       "penalties": {
#          "penalties": 100,
#          "yards": 831
#       },
#       "punt_returns": {
#          "avg_yards": 8.625,
#          "faircatches": 13,
#          "longest": 25,
#          "longest_touchdown": 0,
#          "returns": 16,
#          "touchdowns": 0,
#          "yards": 138
#       },
#       "punts": {
#          "attempts": 55,
#          "avg_hang_time": 4.164,
#          "avg_net_yards": 39.091,
#          "avg_yards": 46.909,
#          "blocked": 0,
#          "hang_time": 229.046,
#          "inside_20": 9,
#          "longest": 63,
#          "net_yards": 2150,
#          "return_yards": 330,
#          "touchbacks": 5,
#          "yards": 2580
#       },
#       "receiving": {
#          "air_yards": 1801,
#          "avg_yards": 10.774,
#          "broken_tackles": 16,
#          "catchable_passes": 29,
#          "dropped_passes": 24,
#          "longest": 67,
#          "longest_touchdown": 67,
#          "receptions": 319,
#          "redzone_targets": 63,
#          "targets": 518,
#          "touchdowns": 21,
#          "yards": 3437,
#          "yards_after_catch": 1636,
#          "yards_after_contact": 496
#       },
#       "rushing": {
#          "attempts": 464,
#          "avg_yards": 4.532,
#          "broken_tackles": 29,
#          "kneel_downs": 15,
#          "longest": 75,
#          "longest_touchdown": 68,
#          "redzone_attempts": 73,
#          "scrambles": 27,
#          "tlost": 26,
#          "tlost_yards": -48,
#          "touchdowns": 9,
#          "yards": 2103,
#          "yards_after_contact": 904
#       },
#       "touchdowns": {
#          "fumble_return": 1,
#          "int_return": 3,
#          "kick_return": 0,
#          "other": 1,
#          "pass": 21,
#          "punt_return": 0,
#          "rush": 9,
#          "total": 35,
#          "total_return": 4
#       }
#    },
#    "players": [
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "0555927e-18ad-40f9-b2d6-f63d533d91aa",
#          "jersey": "0",
#          "name": "LaRoy Reynolds",
#          "position": "LB",
#          "sr_id": "sr:player:829925"
#       },
#       {
#          "games_played": 1,
#          "games_started": 0,
#          "id": "05e15d81-6bb1-49f7-b677-63475d073961",
#          "jersey": "86",
#          "name": "Devin Asiasi",
#          "position": "TE",
#          "sr_id": "sr:player:2040515"
#       },
#       {
#          "defense": {
#             "assists": 23,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 60,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 1,
#             "hurries": 4,
#             "interceptions": 0,
#             "knockdowns": 3,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 6,
#             "passes_defended": 0,
#             "qb_hits": 5,
#             "sack_yards": 9.0,
#             "sacks": 1.5,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 37,
#             "tloss": 2.0,
#             "tloss_yards": 6.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 1,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 17,
#          "games_started": 17,
#          "id": "0861a57d-b468-4c21-ba3a-7523b6838ed0",
#          "jersey": "93",
#          "name": "Lawrence Guy",
#          "penalties": {
#             "first_downs": 1,
#             "penalties": 1,
#             "yards": 6
#          },
#          "position": "DT",
#          "sr_id": "sr:player:831335"
#       },
#       {
#          "defense": {
#             "assists": 24,
#             "batted_passes": 5,
#             "blitzes": 48,
#             "combined": 66,
#             "def_comps": 14,
#             "def_targets": 21,
#             "forced_fumbles": 2,
#             "fumble_recoveries": 1,
#             "hurries": 11,
#             "interceptions": 1,
#             "knockdowns": 2,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 6,
#             "passes_defended": 10,
#             "qb_hits": 7,
#             "sack_yards": 37.0,
#             "sacks": 5.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 42,
#             "tloss": 5.0,
#             "tloss_yards": 38.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 2,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 1,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 16,
#          "games_started": 8,
#          "id": "0ad845ff-44e8-4576-bc91-61b557e06f05",
#          "int_returns": {
#             "avg_yards": 35.0,
#             "longest": 35,
#             "longest_touchdown": 35,
#             "returns": 1,
#             "touchdowns": 1,
#             "yards": 35
#          },
#          "jersey": "8",
#          "name": "Kyle Van Noy",
#          "penalties": {
#             "first_downs": 1,
#             "penalties": 3,
#             "yards": 41
#          },
#          "position": "OLB",
#          "sr_id": "sr:player:830405"
#       },
#       {
#          "defense": {
#             "assists": 12,
#             "batted_passes": 0,
#             "blitzes": 5,
#             "combined": 47,
#             "def_comps": 37,
#             "def_targets": 65,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 1,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 6,
#             "passes_defended": 7,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 35,
#             "tloss": 1.0,
#             "tloss_yards": 2.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 1,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 16,
#          "games_started": 16,
#          "id": "12563365-b4aa-4b85-93a3-b220c8212707",
#          "jersey": "2",
#          "name": "Jalen Mills",
#          "penalties": {
#             "first_downs": 3,
#             "penalties": 3,
#             "yards": 52
#          },
#          "position": "CB",
#          "sr_id": "sr:player:988775"
#       },
#       {
#          "defense": {
#             "assists": 1,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 2,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 0,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 1,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 17,
#          "games_started": 6,
#          "id": "12b701c8-7f40-4437-aeef-782fd1d25f2e",
#          "jersey": "45",
#          "kick_returns": {
#             "avg_yards": 14.0,
#             "faircatches": 0,
#             "longest": 14,
#             "longest_touchdown": 0,
#             "returns": 1,
#             "touchdowns": 0,
#             "yards": 14
#          },
#          "name": "Jakob Johnson",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 1,
#             "yards": 10
#          },
#          "position": "FB",
#          "receiving": {
#             "air_yards": 9,
#             "avg_yards": 10.75,
#             "broken_tackles": 1,
#             "catchable_passes": 0,
#             "dropped_passes": 0,
#             "first_downs": 2,
#             "longest": 29,
#             "longest_touchdown": 0,
#             "receptions": 4,
#             "redzone_targets": 1,
#             "targets": 5,
#             "touchdowns": 0,
#             "yards": 43,
#             "yards_after_catch": 34,
#             "yards_after_contact": 17
#          },
#          "sr_id": "sr:player:1731491"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "133ff990-0b7b-467d-a949-1e1720f96bc9",
#          "jersey": "0",
#          "name": "Alex Redmond",
#          "position": "G",
#          "sr_id": "sr:player:990127"
#       },
#       {
#          "defense": {
#             "assists": 6,
#             "batted_passes": 0,
#             "blitzes": 3,
#             "combined": 20,
#             "def_comps": 10,
#             "def_targets": 18,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 1,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 0,
#             "passes_defended": 5,
#             "qb_hits": 1,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 1,
#             "tackles": 14,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 12,
#          "games_started": 1,
#          "id": "154d65c6-b3fc-4ac4-99a6-48c191e90ffc",
#          "jersey": "33",
#          "name": "Joejuan Williams",
#          "penalties": {
#             "first_downs": 1,
#             "penalties": 2,
#             "yards": 6
#          },
#          "position": "CB",
#          "sr_id": "sr:player:1181472"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "15dcfb8e-ef29-40f4-a924-f3ce4150c563",
#          "jersey": "0",
#          "name": "Quinn Nordin",
#          "position": "K",
#          "sr_id": "sr:player:2198058"
#       },
#       {
#          "games_played": 9,
#          "games_started": 9,
#          "id": "173831a7-d33d-4d2a-8dd9-4e36182e23cc",
#          "jersey": "77",
#          "name": "Trent Brown",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 1,
#             "yards": 15
#          },
#          "position": "OL",
#          "sr_id": "sr:player:835227"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "1ae787ee-d2c3-4ed6-993d-6eabcfbb57f4",
#          "jersey": "0",
#          "name": "Drake Jackson",
#          "position": "C",
#          "sr_id": "sr:player:2198706"
#       },
#       {
#          "defense": {
#             "assists": 0,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 1,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 0,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 1,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 7,
#          "games_started": 2,
#          "id": "1be82e0f-4b22-4a82-b3fc-5835aa214f7a",
#          "jersey": "72",
#          "name": "Yodny Cajuste",
#          "position": "OL",
#          "sr_id": "sr:player:1197306"
#       },
#       {
#          "defense": {
#             "assists": 21,
#             "batted_passes": 0,
#             "blitzes": 11,
#             "combined": 84,
#             "def_comps": 32,
#             "def_targets": 50,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 1,
#             "hurries": 0,
#             "interceptions": 4,
#             "knockdowns": 2,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 9,
#             "passes_defended": 5,
#             "qb_hits": 2,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 1,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 7,
#             "tackles": 63,
#             "tloss": 5.0,
#             "tloss_yards": 7.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 1,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 15,
#          "games_started": 13,
#          "id": "1d8d5c04-15e7-4346-9d1f-f128e4df3adb",
#          "int_returns": {
#             "avg_yards": 25.0,
#             "longest": 37,
#             "longest_touchdown": 0,
#             "returns": 4,
#             "touchdowns": 0,
#             "yards": 100
#          },
#          "jersey": "23",
#          "name": "Kyle Dugger",
#          "penalties": {
#             "first_downs": 1,
#             "penalties": 1,
#             "yards": 46
#          },
#          "position": "DB",
#          "sr_id": "sr:player:2040541"
#       },
#       {
#          "conversions": {
#             "defense_attempts": 0,
#             "defense_successes": 0,
#             "pass_attempts": 2,
#             "pass_successes": 2,
#             "receive_attempts": 0,
#             "receive_successes": 0,
#             "rush_attempts": 0,
#             "rush_successes": 0
#          },
#          "defense": {
#             "assists": 1,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 2,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 1,
#             "misc_tackles": 0,
#             "missed_tackles": 0,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 1,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 7,
#             "lost_fumbles": 3,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 1,
#             "own_rec_tds": 0,
#             "own_rec_yards": -4
#          },
#          "games_played": 17,
#          "games_started": 17,
#          "id": "1fd00ec3-b758-46d2-a2c1-cca521ea8a54",
#          "jersey": "10",
#          "name": "Mac Jones",
#          "passing": {
#             "air_yards": 2027,
#             "attempts": 521,
#             "avg_pocket_time": 2.537,
#             "avg_yards": 7.296,
#             "batted_passes": 9,
#             "blitzes": 181,
#             "cmp_pct": 67.562,
#             "completions": 352,
#             "defended_passes": 50,
#             "dropped_passes": 16,
#             "first_downs": 177,
#             "gross_yards": 3801,
#             "hurries": 29,
#             "int_touchdowns": 0,
#             "interceptions": 13,
#             "knockdowns": 47,
#             "longest": 75,
#             "longest_touchdown": 75,
#             "net_yards": 3560,
#             "on_target_throws": 386,
#             "pocket_time": 1321.602,
#             "poor_throws": 90,
#             "rating": 92.5,
#             "redzone_attempts": 71,
#             "sack_yards": 241,
#             "sacks": 28,
#             "spikes": 1,
#             "throw_aways": 12,
#             "touchdowns": 22,
#             "yards": 3801
#          },
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 2,
#             "yards": 14
#          },
#          "position": "QB",
#          "rushing": {
#             "attempts": 44,
#             "avg_yards": 2.932,
#             "broken_tackles": 0,
#             "first_downs": 22,
#             "kneel_downs": 8,
#             "longest": 13,
#             "longest_touchdown": 0,
#             "redzone_attempts": 7,
#             "scrambles": 15,
#             "tlost": 0,
#             "tlost_yards": 0,
#             "touchdowns": 0,
#             "yards": 129,
#             "yards_after_contact": 34
#          },
#          "sr_id": "sr:player:1235378"
#       },
#       {
#          "defense": {
#             "assists": 13,
#             "batted_passes": 4,
#             "blitzes": 0,
#             "combined": 41,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 1,
#             "fumble_recoveries": 0,
#             "hurries": 8,
#             "interceptions": 0,
#             "knockdowns": 6,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 3,
#             "passes_defended": 4,
#             "qb_hits": 9,
#             "sack_yards": 22.5,
#             "sacks": 3.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 28,
#             "tloss": 4.0,
#             "tloss_yards": 13.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 1,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 16,
#          "games_started": 9,
#          "id": "2516f9e7-9927-409d-adbe-b32d680ae71d",
#          "jersey": "91",
#          "name": "Deatrich Wise Jr.",
#          "penalties": {
#             "first_downs": 2,
#             "penalties": 4,
#             "yards": 46
#          },
#          "position": "DE",
#          "sr_id": "sr:player:1130123"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "25bc08ac-8420-4340-94c6-93993ff87d6f",
#          "jersey": "36",
#          "name": "Devine Ozigbo",
#          "position": "RB",
#          "sr_id": "sr:player:1223764"
#       },
#       {
#          "games_played": 1,
#          "games_started": 0,
#          "id": "25e58aee-1b33-4468-9a81-6586426b91d5",
#          "jersey": "0",
#          "name": "Matt LaCosse",
#          "position": "TE",
#          "sr_id": "sr:player:855690"
#       },
#       {
#          "defense": {
#             "assists": 0,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 1,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 0,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 1,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 16,
#          "games_started": 15,
#          "id": "27b1ba46-842b-4bca-a434-56c60102c1b5",
#          "jersey": "76",
#          "name": "Isaiah Wynn",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 8,
#             "yards": 65
#          },
#          "position": "OL",
#          "sr_id": "sr:player:1202868"
#       },
#       {
#          "defense": {
#             "assists": 0,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 3,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 0,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 3,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 4,
#          "games_started": 0,
#          "id": "2d3a6c81-183f-431b-9b3f-d7f1ce2b294b",
#          "jersey": "94",
#          "name": "Henry Anderson",
#          "position": "DL",
#          "sr_id": "sr:player:834757"
#       },
#       {
#          "defense": {
#             "assists": 41,
#             "batted_passes": 0,
#             "blitzes": 33,
#             "combined": 108,
#             "def_comps": 29,
#             "def_targets": 43,
#             "forced_fumbles": 3,
#             "fumble_recoveries": 0,
#             "hurries": 3,
#             "interceptions": 0,
#             "knockdowns": 5,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 8,
#             "passes_defended": 2,
#             "qb_hits": 5,
#             "sack_yards": 0.0,
#             "sacks": 1.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 1,
#             "tackles": 67,
#             "tloss": 5.0,
#             "tloss_yards": 11.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 3,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 16,
#          "games_started": 16,
#          "id": "3164fc4b-b2ae-43b3-9ff1-1d5f744b9f88",
#          "jersey": "8",
#          "name": "Ja'Whaun Bentley",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 1,
#             "yards": 5
#          },
#          "position": "LB",
#          "sr_id": "sr:player:1227326"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "32b2d6f6-a636-4d73-927c-361c1aa809f5",
#          "jersey": "17",
#          "name": "Corliss Waitman",
#          "position": "P",
#          "sr_id": "sr:player:1192416"
#       },
#       {
#          "defense": {
#             "assists": 23,
#             "batted_passes": 2,
#             "blitzes": 0,
#             "combined": 46,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 9,
#             "interceptions": 0,
#             "knockdowns": 7,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 2,
#             "passes_defended": 2,
#             "qb_hits": 9,
#             "sack_yards": 15.0,
#             "sacks": 1.5,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 23,
#             "tloss": 3.0,
#             "tloss_yards": 13.0
#          },
#          "games_played": 17,
#          "games_started": 2,
#          "id": "39017237-0575-4984-b784-954a79c2bba2",
#          "jersey": "90",
#          "name": "Christian Barmore",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 1,
#             "yards": 5
#          },
#          "position": "DT",
#          "sr_id": "sr:player:2197758"
#       },
#       {
#          "games_played": 3,
#          "games_started": 0,
#          "id": "39f70428-a78a-494c-8676-438d953c289e",
#          "jersey": "0",
#          "name": "James White",
#          "position": "RB",
#          "receiving": {
#             "air_yards": 24,
#             "avg_yards": 7.833,
#             "broken_tackles": 1,
#             "catchable_passes": 1,
#             "dropped_passes": 1,
#             "first_downs": 5,
#             "longest": 28,
#             "longest_touchdown": 0,
#             "receptions": 12,
#             "redzone_targets": 1,
#             "targets": 14,
#             "touchdowns": 0,
#             "yards": 94,
#             "yards_after_catch": 70,
#             "yards_after_contact": 23
#          },
#          "rushing": {
#             "attempts": 10,
#             "avg_yards": 3.8,
#             "broken_tackles": 0,
#             "first_downs": 4,
#             "kneel_downs": 0,
#             "longest": 10,
#             "longest_touchdown": 7,
#             "redzone_attempts": 2,
#             "scrambles": 0,
#             "tlost": 2,
#             "tlost_yards": -2,
#             "touchdowns": 1,
#             "yards": 38,
#             "yards_after_contact": 8
#          },
#          "sr_id": "sr:player:830197"
#       },
#       {
#          "defense": {
#             "assists": 35,
#             "batted_passes": 0,
#             "blitzes": 16,
#             "combined": 87,
#             "def_comps": 34,
#             "def_targets": 57,
#             "forced_fumbles": 1,
#             "fumble_recoveries": 0,
#             "hurries": 2,
#             "interceptions": 4,
#             "knockdowns": 1,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 7,
#             "passes_defended": 9,
#             "qb_hits": 1,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 1,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 4,
#             "tackles": 52,
#             "tloss": 3.0,
#             "tloss_yards": 6.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 1,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 17,
#          "games_started": 13,
#          "id": "3c119ef7-fe68-439d-93e4-89ab4fd1df44",
#          "int_returns": {
#             "avg_yards": 9.75,
#             "longest": 26,
#             "longest_touchdown": 26,
#             "returns": 4,
#             "touchdowns": 1,
#             "yards": 39
#          },
#          "jersey": "21",
#          "name": "Adrian Phillips",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 1,
#             "yards": 10
#          },
#          "position": "DB",
#          "sr_id": "sr:player:855330"
#       },
#       {
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 1,
#             "lost_fumbles": 1,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 12,
#          "games_started": 4,
#          "id": "3e6e15ce-1c81-408e-9a94-b0a2924d0b8c",
#          "jersey": "8",
#          "name": "N'Keal Harry",
#          "position": "WR",
#          "punt_returns": {
#             "avg_yards": 0.0,
#             "faircatches": 0,
#             "longest": 0,
#             "longest_touchdown": 0,
#             "returns": 1,
#             "touchdowns": 0,
#             "yards": 0
#          },
#          "receiving": {
#             "air_yards": 159,
#             "avg_yards": 15.333,
#             "broken_tackles": 0,
#             "catchable_passes": 1,
#             "dropped_passes": 1,
#             "first_downs": 7,
#             "longest": 43,
#             "longest_touchdown": 0,
#             "receptions": 12,
#             "redzone_targets": 1,
#             "targets": 22,
#             "touchdowns": 0,
#             "yards": 184,
#             "yards_after_catch": 25,
#             "yards_after_contact": 10
#          },
#          "sr_id": "sr:player:1734449"
#       },
#       {
#          "games_played": 16,
#          "games_started": 8,
#          "id": "3ee844af-9408-42d7-ba42-aaa2d5ccc673",
#          "jersey": "71",
#          "name": "Mike Onwenu",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 3,
#             "yards": 25
#          },
#          "position": "OL",
#          "sr_id": "sr:player:2040487"
#       },
#       {
#          "defense": {
#             "assists": 1,
#             "batted_passes": 0,
#             "blitzes": 1,
#             "combined": 3,
#             "def_comps": 2,
#             "def_targets": 3,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 1,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 1,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 2,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 3,
#          "games_started": 1,
#          "id": "3f0926f7-103e-44d5-85f0-e53ec48fe452",
#          "jersey": "35",
#          "name": "D'Angelo Ross",
#          "position": "DB",
#          "sr_id": "sr:player:1741297"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "3fa97e08-13d9-47a8-b155-39f975964d47",
#          "jersey": "68",
#          "name": "Byron Cowart",
#          "position": "DT",
#          "sr_id": "sr:player:1221760"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "416e8e41-9e8f-4bc9-9d26-babb37bec884",
#          "jersey": "51",
#          "name": "Ronnie Perkins",
#          "position": "LB",
#          "sr_id": "sr:player:1423151"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "49bf0cd8-c01f-4d31-b6f1-fdda02b4999f",
#          "jersey": "0",
#          "name": "Terez Hall",
#          "position": "LB",
#          "sr_id": "sr:player:1220300"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "4a7d7bfc-9fe6-4869-a741-d5d17b177edc",
#          "jersey": "0",
#          "name": "Elijah Benton",
#          "position": "SAF",
#          "sr_id": "sr:player:1184114"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "4da5e05d-fc5c-4e87-aa38-d9cde42dd476",
#          "jersey": "0",
#          "name": "Dalton Keene",
#          "position": "TE",
#          "sr_id": "sr:player:2039959"
#       },
#       {
#          "defense": {
#             "assists": 0,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 0,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 1,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 6,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 9,
#             "tackles": 0,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 17,
#          "games_started": 0,
#          "id": "4f454037-be8e-4575-b332-5e40f4788970",
#          "jersey": "22",
#          "name": "Cody Davis",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 1,
#             "yards": 10
#          },
#          "position": "DB",
#          "sr_id": "sr:player:828755"
#       },
#       {
#          "defense": {
#             "assists": 7,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 19,
#             "def_comps": 1,
#             "def_targets": 1,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 1,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 1,
#             "passes_defended": 0,
#             "qb_hits": 1,
#             "sack_yards": 9.0,
#             "sacks": 1.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 12,
#             "tloss": 1.0,
#             "tloss_yards": 9.0
#          },
#          "games_played": 17,
#          "games_started": 4,
#          "id": "50de642a-7e6c-4625-9966-ed8fc64acfa0",
#          "jersey": "98",
#          "name": "Carl Davis Jr.",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 2,
#             "yards": 10
#          },
#          "position": "DL",
#          "sr_id": "sr:player:834729"
#       },
#       {
#          "defense": {
#             "assists": 5,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 18,
#             "def_comps": 22,
#             "def_targets": 34,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 1,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 1,
#             "passes_defended": 3,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 2,
#             "tackles": 13,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 6,
#          "games_started": 1,
#          "id": "537c88d4-c403-43f4-94a1-fdccea0ee24a",
#          "int_returns": {
#             "avg_yards": 0.0,
#             "longest": 0,
#             "longest_touchdown": 0,
#             "returns": 1,
#             "touchdowns": 0,
#             "yards": 0
#          },
#          "jersey": "31",
#          "name": "Jonathan Jones",
#          "position": "DB",
#          "sr_id": "sr:player:989241"
#       },
#       {
#          "defense": {
#             "assists": 1,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 5,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 0,
#             "passes_defended": 0,
#             "qb_hits": 2,
#             "sack_yards": 13.0,
#             "sacks": 2.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 4,
#             "tloss": 2.0,
#             "tloss_yards": 13.0
#          },
#          "games_played": 7,
#          "games_started": 0,
#          "id": "55998ec0-4d69-4d14-a2f4-cf72de36e998",
#          "jersey": "95",
#          "name": "Daniel Ekuale",
#          "position": "DT",
#          "sr_id": "sr:player:1226594"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "56073e7b-84ca-4d4a-a2e7-1bfc0277e8d4",
#          "jersey": "0",
#          "name": "Garrett Gilbert",
#          "position": "QB",
#          "sr_id": "sr:player:829755"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "56692800-dd44-4b82-a988-398314845fd9",
#          "jersey": "58",
#          "name": "Anfernee Jennings",
#          "position": "LB",
#          "sr_id": "sr:player:2040297"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "579d92e6-ab4f-43e0-803f-b2d5a54d106a",
#          "jersey": "49",
#          "name": "Troy Fumagalli",
#          "position": "TE",
#          "sr_id": "sr:player:1217502"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "582fe465-135a-4901-beef-60aebce99067",
#          "jersey": "3",
#          "name": "Jarrett Stidham",
#          "position": "QB",
#          "sr_id": "sr:player:1232264"
#       },
#       {
#          "defense": {
#             "assists": 0,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 0,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 1,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 0,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 2,
#             "lost_fumbles": 2,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 2,
#             "own_rec_tds": 0,
#             "own_rec_yards": 2
#          },
#          "games_played": 15,
#          "games_started": 15,
#          "id": "59482736-ce42-4058-b68e-0f9f66eac2d9",
#          "jersey": "37",
#          "name": "Damien Harris",
#          "position": "RB",
#          "receiving": {
#             "air_yards": -2,
#             "avg_yards": 7.333,
#             "broken_tackles": 1,
#             "catchable_passes": 1,
#             "dropped_passes": 0,
#             "first_downs": 4,
#             "longest": 21,
#             "longest_touchdown": 0,
#             "receptions": 18,
#             "redzone_targets": 2,
#             "targets": 21,
#             "touchdowns": 0,
#             "yards": 132,
#             "yards_after_catch": 134,
#             "yards_after_contact": 19
#          },
#          "rushing": {
#             "attempts": 202,
#             "avg_yards": 4.599,
#             "broken_tackles": 15,
#             "first_downs": 55,
#             "kneel_downs": 0,
#             "longest": 64,
#             "longest_touchdown": 64,
#             "redzone_attempts": 44,
#             "scrambles": 0,
#             "tlost": 19,
#             "tlost_yards": -45,
#             "touchdowns": 15,
#             "yards": 929,
#             "yards_after_contact": 460
#          },
#          "sr_id": "sr:player:1216208"
#       },
#       {
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 1,
#             "lost_fumbles": 1,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 17,
#          "games_started": 5,
#          "id": "5aba3610-ab55-4922-ac46-806ded5eb8bf",
#          "jersey": "84",
#          "name": "Kendrick Bourne",
#          "passing": {
#             "air_yards": 22,
#             "attempts": 1,
#             "avg_pocket_time": 1.565,
#             "avg_yards": 25.0,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "cmp_pct": 100.0,
#             "completions": 1,
#             "defended_passes": 0,
#             "dropped_passes": 0,
#             "first_downs": 1,
# ...
#             "penalties": 1,
#             "yards": 15
#          },
#          "position": "RB",
#          "receiving": {
#             "air_yards": -11,
#             "avg_yards": 9.878,
#             "broken_tackles": 10,
#             "catchable_passes": 2,
#             "dropped_passes": 2,
#             "first_downs": 21,
#             "longest": 28,
#             "longest_touchdown": 18,
#             "receptions": 41,
#             "redzone_targets": 9,
#             "targets": 49,
#             "touchdowns": 2,
#             "yards": 405,
#             "yards_after_catch": 416,
#             "yards_after_contact": 109
#          },
#          "rushing": {
#             "attempts": 44,
#             "avg_yards": 5.136,
#             "broken_tackles": 2,
#             "first_downs": 12,
#             "kneel_downs": 0,
#             "longest": 24,
#             "longest_touchdown": 15,
#             "redzone_attempts": 8,
#             "scrambles": 0,
#             "tlost": 7,
#             "tlost_yards": -8,
#             "touchdowns": 1,
#             "yards": 226,
#             "yards_after_contact": 121
#          },
#          "sr_id": "sr:player:829147"
#       },
#       {
#          "games_played": 0,
#          "games_started": 0,
#          "id": "deac735c-af0a-4f01-ada8-379ef66917ba",
#          "jersey": "6",
#          "name": "Riley Patterson",
#          "position": "K",
#          "sr_id": "sr:player:2198528"
#       },
#       {
#          "defense": {
#             "assists": 3,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 6,
#             "def_comps": 5,
#             "def_targets": 5,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 1,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 2,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 5,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 3,
#             "tackles": 3,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 1,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 13,
#          "games_started": 0,
#          "id": "dfb05fbc-7329-4893-8dc1-3d30033e49d0",
#          "jersey": "48",
#          "name": "Jahlani Tavai",
#          "position": "LB",
#          "sr_id": "sr:player:1184342"
#       },
#       {
#          "defense": {
#             "assists": 0,
#             "batted_passes": 0,
#             "blitzes": 1,
#             "combined": 0,
#             "def_comps": 0,
#             "def_targets": 0,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 1,
#             "passes_defended": 0,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 0,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "games_played": 2,
#          "games_started": 0,
#          "id": "dfb0b126-9c75-41d3-9371-04065db7506a",
#          "jersey": "0",
#          "name": "Sean Davis",
#          "position": "SAF",
#          "sr_id": "sr:player:1074044"
#       },
#       {
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 1,
#             "lost_fumbles": 0,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 2,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 16,
#          "games_started": 11,
#          "id": "e4f25a37-74de-4bfb-b6c9-f50a4fab0b87",
#          "jersey": "81",
#          "name": "Jonnu Smith",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 5,
#             "yards": 40
#          },
#          "position": "TE",
#          "receiving": {
#             "air_yards": 62,
#             "avg_yards": 10.5,
#             "broken_tackles": 2,
#             "catchable_passes": 4,
#             "dropped_passes": 4,
#             "first_downs": 15,
#             "longest": 28,
#             "longest_touchdown": 1,
#             "receptions": 28,
#             "redzone_targets": 10,
#             "targets": 45,
#             "touchdowns": 1,
#             "yards": 294,
#             "yards_after_catch": 232,
#             "yards_after_contact": 80
#          },
#          "rushing": {
#             "attempts": 9,
#             "avg_yards": 4.444,
#             "broken_tackles": 0,
#             "first_downs": 2,
#             "kneel_downs": 0,
#             "longest": 9,
#             "longest_touchdown": 0,
#             "redzone_attempts": 2,
#             "scrambles": 0,
#             "tlost": 1,
#             "tlost_yards": -1,
#             "touchdowns": 0,
#             "yards": 40,
#             "yards_after_contact": 24
#          },
#          "sr_id": "sr:player:1129751"
#       },
#       {
#          "defense": {
#             "assists": 25,
#             "batted_passes": 1,
#             "blitzes": 36,
#             "combined": 64,
#             "def_comps": 28,
#             "def_targets": 31,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 7,
#             "interceptions": 0,
#             "knockdowns": 1,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 10,
#             "passes_defended": 1,
#             "qb_hits": 4,
#             "sack_yards": 13.5,
#             "sacks": 1.5,
#             "safeties": 0,
#             "sp_assists": 0,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 0,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 0,
#             "tackles": 39,
#             "tloss": 1.0,
#             "tloss_yards": 9.0
#          },
#          "games_played": 15,
#          "games_started": 15,
#          "id": "e7a18744-0608-4118-888f-f51de5645ce9",
#          "jersey": "54",
#          "name": "Dont'a Hightower",
#          "penalties": {
#             "first_downs": 1,
#             "penalties": 1,
#             "yards": 7
#          },
#          "position": "LB",
#          "sr_id": "sr:player:827685"
#       },
#       {
#          "games_played": 1,
#          "games_started": 0,
#          "id": "e94705dd-635c-45f0-b243-88bdd92b4adf",
#          "jersey": "68",
#          "name": "Will Sherman",
#          "position": "T",
#          "sr_id": "sr:player:2197718"
#       },
#       {
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 0,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 1,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 7,
#          "games_started": 1,
#          "id": "ed37f30a-de45-4af6-b7b5-5f218bf786ab",
#          "jersey": "70",
#          "name": "Yasir Durant",
#          "position": "G",
#          "sr_id": "sr:player:1236782"
#       },
#       {
#          "defense": {
#             "assists": 0,
#             "batted_passes": 0,
#             "blitzes": 0,
#             "combined": 4,
#             "def_comps": 6,
#             "def_targets": 8,
#             "forced_fumbles": 0,
#             "fumble_recoveries": 0,
#             "hurries": 0,
#             "interceptions": 0,
#             "knockdowns": 0,
#             "misc_assists": 0,
#             "misc_forced_fumbles": 0,
#             "misc_fumble_recoveries": 0,
#             "misc_tackles": 0,
#             "missed_tackles": 0,
#             "passes_defended": 1,
#             "qb_hits": 0,
#             "sack_yards": 0.0,
#             "sacks": 0.0,
#             "safeties": 0,
#             "sp_assists": 3,
#             "sp_blocks": 0,
#             "sp_forced_fumbles": 1,
#             "sp_fumble_recoveries": 0,
#             "sp_tackles": 5,
#             "tackles": 4,
#             "tloss": 0.0,
#             "tloss_yards": 0.0
#          },
#          "fumbles": {
#             "ez_rec_tds": 0,
#             "forced_fumbles": 1,
#             "fumbles": 0,
#             "lost_fumbles": 0,
#             "opp_rec": 0,
#             "opp_rec_tds": 0,
#             "opp_rec_yards": 0,
#             "out_of_bounds": 0,
#             "own_rec": 0,
#             "own_rec_tds": 0,
#             "own_rec_yards": 0
#          },
#          "games_played": 17,
#          "games_started": 0,
#          "id": "f403d099-29d4-43cd-bf79-4aeeb8dc6cd3",
#          "jersey": "29",
#          "name": "Justin Bethel",
#          "penalties": {
#             "first_downs": 0,
#             "penalties": 1,
#             "yards": 10
#          },
#          "position": "DB",
#          "sr_id": "sr:player:829839"
#       }
#    ],
#    "record": {
#       "defense": {
#          "assists": 364,
#          "batted_passes": 12,
#          "blitzes": 253,
#          "combined": 1023,
#          "def_comps": 326,
#          "def_targets": 531,
#          "forced_fumbles": 10,
#          "fumble_recoveries": 7,
#          "hurries": 75,
#          "interceptions": 23,
#          "knockdowns": 43,
#          "misc_assists": 0,
#          "misc_forced_fumbles": 0,
#          "misc_fumble_recoveries": 1,
#          "misc_tackles": 4,
#          "missed_tackles": 95,
#          "passes_defended": 89,
#          "qb_hits": 86,
#          "sack_yards": 256.0,
#          "sacks": 36.0,
#          "safeties": 0,
#          "sp_assists": 38,
#          "sp_blocks": 0,
#          "sp_forced_fumbles": 1,
#          "sp_fumble_recoveries": 1,
#          "sp_tackles": 59,
#          "tackles": 659,
#          "tloss": 60.0,
#          "tloss_yards": 283.0
#       },
#       "efficiency": {
#          "fourthdown": {
#             "attempts": 17,
#             "pct": 64.706,
#             "successes": 11
#          },
#          "goaltogo": {
#             "attempts": 31,
#             "pct": 77.419,
#             "successes": 24
#          },
#          "redzone": {
#             "attempts": 63,
#             "pct": 61.905,
#             "successes": 39
#          },
#          "thirddown": {
#             "attempts": 209,
#             "pct": 43.541,
#             "successes": 91
#          }
#       },
#       "extra_points": {
#          "conversions": {
#             "defense_attempts": 0,
#             "defense_successes": 0,
#             "pass_attempts": 2,
#             "pass_successes": 2,
#             "rush_attempts": 2,
#             "rush_successes": 1,
#             "turnover_successes": 0
#          },
#          "kicks": {
#             "attempts": 47,
#             "blocked": 1,
#             "made": 42,
#             "pct": 89.362
#          }
#       },
#       "field_goals": {
#          "attempts": 39,
#          "attempts_19": 0,
#          "attempts_29": 9,
#          "attempts_39": 11,
#          "attempts_49": 11,
#          "attempts_50": 8,
#          "avg_yards": 34.718,
#          "blocked": 0,
#          "longest": 53,
#          "made": 36,
#          "made_19": 0,
#          "made_29": 9,
#          "made_39": 11,
#          "made_49": 11,
#          "made_50": 5,
#          "missed": 3,
#          "pct": 92.308,
#          "yards": 1354
#       },
#       "first_downs": {
#          "pass": 187,
#          "penalty": 36,
#          "rush": 139,
#          "total": 362
#       },
#       "fumbles": {
#          "ez_rec_tds": 0,
#          "forced_fumbles": 11,
#          "fumbles": 20,
#          "lost_fumbles": 10,
#          "opp_rec": 7,
#          "opp_rec_tds": 0,
#          "opp_rec_yards": -6,
#          "out_of_bounds": 0,
#          "own_rec": 9,
#          "own_rec_tds": 0,
#          "own_rec_yards": -2
#       },
#       "games_played": 17,
#       "int_returns": {
#          "avg_yards": 14.0,
#          "longest": 88,
#          "longest_touchdown": 88,
#          "returns": 23,
#          "touchdowns": 3,
#          "yards": 322
#       },
#       "interceptions": {
#          "interceptions": 23,
#          "return_yards": 322,
#          "returned": 23
#       },
#       "kick_returns": {
#          "avg_yards": 21.76,
#          "faircatches": 0,
#          "longest": 37,
#          "longest_touchdown": 0,
#          "returns": 25,
#          "touchdowns": 0,
#          "yards": 544
#       },
#       "kickoffs": {
#          "endzone": 18,
#          "inside_20": 8,
#          "kickoffs": 103,
#          "onside_attempts": 0,
#          "onside_successes": 0,
#          "out_of_bounds": 3,
#          "return_yards": 1223,
#          "returned": 0,
#          "squib_kicks": 1,
#          "touchbacks": 45,
#          "yards": 6497
#       },
#       "passing": {
#          "air_yards": 2144,
#          "attempts": 535,
#          "avg_yards": 7.66,
#          "batted_passes": 9,
#          "blitzes": 185,
#          "cmp_pct": 68.037,
#          "completions": 364,
#          "defended_passes": 52,
#          "dropped_passes": 16,
#          "gross_yards": 4098,
#          "hurries": 29,
#          "int_touchdowns": 0,
#          "interceptions": 13,
#          "knockdowns": 48,
#          "longest": 75,
#          "longest_touchdown": 75,
#          "net_yards": 3857,
#          "on_target_throws": 400,
#          "pocket_time": 1352.1409999999998,
#          "poor_throws": 90,
#          "rating": 95.5,
#          "redzone_attempts": 73,
#          "sack_yards": 241,
#          "sacks": 28,
#          "spikes": 1,
#          "throw_aways": 12,
#          "touchdowns": 24,
#          "yards": 3857
#       },
#       "penalties": {
#          "penalties": 95,
#          "yards": 854
#       },
#       "punt_returns": {
#          "avg_yards": 11.286,
#          "faircatches": 12,
#          "longest": 27,
#          "longest_touchdown": 0,
#          "returns": 28,
#          "touchdowns": 0,
#          "yards": 316
#       },
#       "punts": {
#          "attempts": 51,
#          "avg_hang_time": 4.252,
#          "avg_net_yards": 40.353,
#          "avg_yards": 45.412,
#          "blocked": 3,
#          "hang_time": 204.08300000000003,
#          "inside_20": 23,
#          "longest": 71,
#          "net_yards": 2058,
#          "return_yards": 138,
#          "touchbacks": 6,
#          "yards": 2316
#       },
#       "receiving": {
#          "air_yards": 2144,
#          "avg_yards": 11.258,
#          "broken_tackles": 31,
#          "catchable_passes": 22,
#          "dropped_passes": 16,
#          "longest": 75,
#          "longest_touchdown": 75,
#          "receptions": 364,
#          "redzone_targets": 70,
#          "targets": 524,
#          "touchdowns": 24,
#          "yards": 4098,
#          "yards_after_catch": 1954,
#          "yards_after_contact": 539
#       },
#       "rushing": {
#          "attempts": 489,
#          "avg_yards": 4.399,
#          "broken_tackles": 37,
#          "kneel_downs": 18,
#          "longest": 64,
#          "longest_touchdown": 64,
#          "redzone_attempts": 93,
#          "scrambles": 15,
#          "tlost": 48,
#          "tlost_yards": -88,
#          "touchdowns": 24,
#          "yards": 2151,
#          "yards_after_contact": 1064
#       },
#       "touchdowns": {
#          "fumble_return": 0,
#          "int_return": 3,
#          "kick_return": 0,
#          "other": 0,
#          "pass": 24,
#          "punt_return": 0,
#          "rush": 24,
#          "total": 51,
#          "total_return": 3
#       }
#    },
#    "season": {
#       "id": "06275f0f-08ff-4787-91fc-5c30464ccfd9",
#       "name": "REG",
#       "type": "REG",
#       "year": 2021
#    },
#    "sr_id": "sr:competitor:4424"
# }
